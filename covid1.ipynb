# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split 
from statsmodels.tsa.stattools import adfuller 
from statsmodels.tsa.ar_model import AutoReg

# %%
covid = pd.read_csv('Complete_covid19_dataset.csv')

# %%
vaccination = pd.read_csv('Covid19-vaccination.csv')

# %%
# Check the number of the features and the observations
print('The COVID Dataset shape is',covid.shape)
print('The vaccination Dataset shape is',vaccination.shape)
# Out:
# The COVID Dataset shape is (134459, 67)
# The vaccination Dataset shape is (63006, 16)

# %%
vaccination.isnull().sum()/len(vaccination)
# Out:
# location                               0.000000
# iso_code                               0.000000
# date                                   0.000000
# total_vaccinations                     0.432927
# people_vaccinated                      0.458417
# people_fully_vaccinated                0.505555
# total_boosters                         0.895042
# daily_vaccinations_raw                 0.525077
# daily_vaccinations                     0.005174
# total_vaccinations_per_hundred         0.432927
# people_vaccinated_per_hundred          0.458417
# people_fully_vaccinated_per_hundred    0.505555
# total_boosters_per_hundred             0.895042
# daily_vaccinations_per_million         0.005174
# daily_people_vaccinated                0.024728
# daily_people_vaccinated_per_hundred    0.024728
# dtype: float64

# %%
vaccination = vaccination.drop(vaccination[vaccination.total_vaccinations.isna()].index)
vaccination.shape
# Out:
# (35729, 16)

# %%
# Create a new dataframe
vaccination1 = vaccination.drop(vaccination[vaccination.people_vaccinated.isna()].index)
vaccination1.head()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Afghanistan      AFG  2021-02-22                 0.0                0.0
# 6   Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 22  Afghanistan      AFG  2021-03-16             54000.0            54000.0
# 44  Afghanistan      AFG  2021-04-07            120000.0           120000.0
# 59  Afghanistan      AFG  2021-04-22            240000.0           240000.0
#
#     people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                       NaN             NaN                     NaN
# 6                       NaN             NaN                     NaN
# 22                      NaN             NaN                     NaN
# 44                      NaN             NaN                     NaN
# 59                      NaN             NaN                     NaN
#
#     daily_vaccinations  total_vaccinations_per_hundred  \
# 0                  NaN                            0.00
# 6               1367.0                            0.02
# 22              2862.0                            0.14
# 44              3000.0                            0.30
# 59              8000.0                            0.60
#
#     people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.00                                  NaN
# 6                            0.02                                  NaN
# 22                           0.14                                  NaN
# 44                           0.30                                  NaN
# 59                           0.60                                  NaN
#
#     total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                          NaN                             NaN
# 6                          NaN                            34.0
# 22                         NaN                            72.0
# 44                         NaN                            75.0
# 59                         NaN                           201.0
#
#     daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                       NaN                                  NaN
# 6                    1367.0                                0.003
# 22                   2862.0                                0.007
# 44                   3000.0                                0.008
# 59                   8000.0                                0.020

# %%
# plt.subplots(figsize=(12, 12))
# sns.heatmap(vaccination1.corr(), annot=True, square=True)
# plt.title('Correlation between each features in Vaccinations Dataframe')
# plt.show()

# %%
vaccination2=vaccination1.drop(vaccination1[vaccination1.people_fully_vaccinated.isna()].index)
vaccination2.shape
# Out:
# (30638, 16)

# %% [markdown]
# ## Shaprio-Wilk Test/ KS Test (Kolmogorov-Smirnov test)
# ### To check normal distribution

# %%
# Shapiro-Wilk test to check whether it is normal distribution
# The shapiro-Wilk's Null Hypothesis is that the data is normal distribution.

w, pvalue = stats.shapiro(vaccination2['people_fully_vaccinated'])
print('W-statistic: %.8f, p-value: %.8f' % (w, pvalue))
# Out:
# W-statistic: 0.18319565, p-value: 0.00000000
# /Users/jinyanhuang/Library/Python/3.9/lib/python/site-packages/scipy/stats/_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
#Shapiro-Wilk test to check whether it is normal distribution
# The shapiro-Wilk's Null Hypothesis is that the data is normal distribution.

w,pvalue = stats.shapiro(vaccination2['total_vaccinations'])
print('W-statistic: %.8f, p-value: %.8f' % (w, pvalue))
# Out:
# W-statistic: 0.20982051, p-value: 0.00000000

# %%
stat, p_value = stats.kstest(vaccination2['total_vaccinations'],'norm')
# Print the test statistic and p-value
print('Statistics=%.3f, p=%.3f' % (stat, p_value))

# Interpret the result
alpha = 0.01
if p_value > alpha:
    print('total_vaccinations looks Gaussian (fail to reject H0)')
else:
    print('total_vaccinations does not look Gaussian (reject H0)')
# Out:
# Statistics=1.000, p=0.000
# total_vaccinations does not look Gaussian (reject H0)

# %%
stat, p_value = stats.kstest(vaccination2['people_fully_vaccinated'],'norm')
# Print the test statistic and p-value
print('Statistics=%.3f, p=%.3f' % (stat, p_value))

# Interpret the result
alpha = 0.01
if p_value > alpha:
    print('people_fully_vaccinated looks Gaussian (fail to reject H0)')
else:
    print('people_fully_vaccinated does not look Gaussian (reject H0)')
# Out:
# Statistics=0.994, p=0.000
# people_fully_vaccinated does not look Gaussian (reject H0)

# %%
# Create a new dataframe 
# Delete the column 'daily_vaccinations' NA rows
vaccination3=vaccination1.drop(vaccination1[vaccination1.daily_vaccinations.isna()].index)
vaccination3.shape
# Out:
# (33635, 16)

# %%
# Create a new dataframe and delete the column 'daily_vaccinations_raw' NA rows
vaccination3=vaccination1.drop(vaccination1[vaccination1.daily_vaccinations_raw.isna()].index)
vaccination3.shape
# Out:
# (28485, 16)

# %%
# Drop the NA values of total vaccinations in covid datatset
covid = covid.drop(covid[covid.total_vaccinations.isna()].index)
covid.shape
# Out:
# (34276, 67)

# %%
# Create a temporary df
covid1 = covid.drop(covid[covid.people_vaccinated.isna()].index)
covid1.shape
# Out:
# (32410, 67)

# %%
# Select the columns that related to the population death rates
new1=covid1.loc[:,'total_deaths':'new_deaths_smoothed_per_million']
new1
# Out:
#         total_deaths  new_deaths  new_deaths_smoothed  \
# 364           2433.0         1.0                0.857
# 370           2443.0         0.0                1.571
# 386           2460.0         1.0                1.286
# 408           2512.0         0.0                4.000
# 423           2561.0         4.0                4.000
# ...              ...         ...                  ...
# 134453        4696.0         0.0                1.571
# 134454        4697.0         1.0                1.000
# 134455        4698.0         1.0                1.000
# 134457        4699.0         0.0                0.714
# 134458        4699.0         0.0                0.714
#
#         total_cases_per_million  new_cases_per_million  \
# 364                    1396.169                  0.326
# 370                    1398.604                  0.176
# 386                    1405.658                  0.251
# 408                    1427.699                  2.360
# 423                    1463.823                  2.460
# ...                         ...                    ...
# 134453                 8840.875                  2.319
# 134454                 8841.538                  0.663
# 134455                 8845.977                  4.439
# 134457                 8851.808                  2.385
# 134458                 8851.808                  0.000
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 364                              0.369                    61.076
# 370                              0.394                    61.327
# 386                              0.427                    61.754
# 408                              1.503                    63.059
# 423                              2.790                    64.290
# ...                                ...                       ...
# 134453                           2.281                   311.155
# 134454                           2.205                   311.221
# 134455                           2.489                   311.287
# 134457                           2.499                   311.353
# 134458                           2.499                   311.353
#
#         new_deaths_per_million  new_deaths_smoothed_per_million
# 364                      0.025                            0.022
# 370                      0.000                            0.039
# 386                      0.025                            0.032
# 408                      0.000                            0.100
# 423                      0.100                            0.100
# ...                        ...                              ...
# 134453                   0.000                            0.104
# 134454                   0.066                            0.066
# 134455                   0.066                            0.066
# 134457                   0.000                            0.047
# 134458                   0.000                            0.047
#
# [32410 rows x 9 columns]

# %%
# Select the columns that related to the numbers of vaccinated people population
new2=covid1.loc[:,'total_vaccinations':'new_people_vaccinated_smoothed']
new2
# Out:
#         total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 364                    0.0                0.0                      NaN
# 370                 8200.0             8200.0                      NaN
# 386                54000.0            54000.0                      NaN
# 408               120000.0           120000.0                      NaN
# 423               240000.0           240000.0                      NaN
# ...                    ...                ...                      ...
# 134453           6165714.0          3469198.0                2696516.0
# 134454           6190303.0          3484207.0                2706096.0
# 134455           6228119.0          3515140.0                2712979.0
# 134457           6310431.0          3583256.0                2727175.0
# 134458           6362499.0          3625221.0                2737278.0
#
#         total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 364                NaN               NaN                        NaN
# 370                NaN               NaN                     1367.0
# 386                NaN               NaN                     2862.0
# 408                NaN               NaN                     3000.0
# 423                NaN               NaN                     8000.0
# ...                ...               ...                        ...
# 134453             NaN           10344.0                    20608.0
# 134454             NaN           24589.0                    22283.0
# 134455             NaN           37816.0                    24487.0
# 134457             NaN               NaN                    29822.0
# 134458             NaN           52068.0                    33163.0
#
#         total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 364                               0.00                           0.00
# 370                               0.02                           0.02
# 386                               0.14                           0.14
# 408                               0.30                           0.30
# 423                               0.60                           0.60
# ...                                ...                            ...
# 134453                           40.85                          22.99
# 134454                           41.02                          23.09
# 134455                           41.27                          23.29
# 134457                           41.81                          23.74
# 134458                           42.16                          24.02
#
#         people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 364                                     NaN                         NaN
# 370                                     NaN                         NaN
# 386                                     NaN                         NaN
# 408                                     NaN                         NaN
# 423                                     NaN                         NaN
# ...                                     ...                         ...
# 134453                                17.87                         NaN
# 134454                                17.93                         NaN
# 134455                                17.98                         NaN
# 134457                                18.07                         NaN
# 134458                                18.14                         NaN
#
#         new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed
# 364                                       NaN                             NaN
# 370                                      34.0                          1367.0
# 386                                      72.0                          2862.0
# 408                                      75.0                          3000.0
# 423                                     201.0                          8000.0
# ...                                       ...                             ...
# 134453                                 1365.0                         13782.0
# 134454                                 1476.0                         14852.0
# 134455                                 1622.0                         17188.0
# 134457                                 1976.0                         22810.0
# 134458                                 2197.0                         25915.0
#
# [32410 rows x 12 columns]

# %%
# Create a new dataframe that includes the country names
new3=covid1.loc[:,'location']
new3
# Out:
# 364       Afghanistan
# 370       Afghanistan
# 386       Afghanistan
# 408       Afghanistan
# 423       Afghanistan
#              ...
# 134453       Zimbabwe
# 134454       Zimbabwe
# 134455       Zimbabwe
# 134457       Zimbabwe
# 134458       Zimbabwe
# Name: location, Length: 32410, dtype: object

# %%
# Concat three dataframes
new_df_part4=pd.concat([new1,new2,new3], axis=1)
new_df_part4
# Out:
#         total_deaths  new_deaths  new_deaths_smoothed  \
# 364           2433.0         1.0                0.857
# 370           2443.0         0.0                1.571
# 386           2460.0         1.0                1.286
# 408           2512.0         0.0                4.000
# 423           2561.0         4.0                4.000
# ...              ...         ...                  ...
# 134453        4696.0         0.0                1.571
# 134454        4697.0         1.0                1.000
# 134455        4698.0         1.0                1.000
# 134457        4699.0         0.0                0.714
# 134458        4699.0         0.0                0.714
#
#         total_cases_per_million  new_cases_per_million  \
# 364                    1396.169                  0.326
# 370                    1398.604                  0.176
# 386                    1405.658                  0.251
# 408                    1427.699                  2.360
# 423                    1463.823                  2.460
# ...                         ...                    ...
# 134453                 8840.875                  2.319
# 134454                 8841.538                  0.663
# 134455                 8845.977                  4.439
# 134457                 8851.808                  2.385
# 134458                 8851.808                  0.000
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 364                              0.369                    61.076
# 370                              0.394                    61.327
# 386                              0.427                    61.754
# 408                              1.503                    63.059
# 423                              2.790                    64.290
# ...                                ...                       ...
# 134453                           2.281                   311.155
# 134454                           2.205                   311.221
# 134455                           2.489                   311.287
# 134457                           2.499                   311.353
# 134458                           2.499                   311.353
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 364                      0.025                            0.022
# 370                      0.000                            0.039
# 386                      0.025                            0.032
# 408                      0.000                            0.100
# 423                      0.100                            0.100
# ...                        ...                              ...
# 134453                   0.000                            0.104
# 134454                   0.066                            0.066
# 134455                   0.066                            0.066
# 134457                   0.000                            0.047
# 134458                   0.000                            0.047
#
#         total_vaccinations  ...  total_boosters  new_vaccinations  \
# 364                    0.0  ...             NaN               NaN
# 370                 8200.0  ...             NaN               NaN
# 386                54000.0  ...             NaN               NaN
# 408               120000.0  ...             NaN               NaN
# 423               240000.0  ...             NaN               NaN
# ...                    ...  ...             ...               ...
# 134453           6165714.0  ...             NaN           10344.0
# 134454           6190303.0  ...             NaN           24589.0
# 134455           6228119.0  ...             NaN           37816.0
# 134457           6310431.0  ...             NaN               NaN
# 134458           6362499.0  ...             NaN           52068.0
#
#         new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 364                           NaN                            0.00
# 370                        1367.0                            0.02
# 386                        2862.0                            0.14
# 408                        3000.0                            0.30
# 423                        8000.0                            0.60
# ...                           ...                             ...
# 134453                    20608.0                           40.85
# 134454                    22283.0                           41.02
# 134455                    24487.0                           41.27
# 134457                    29822.0                           41.81
# 134458                    33163.0                           42.16
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 364                              0.00                                  NaN
# 370                              0.02                                  NaN
# 386                              0.14                                  NaN
# 408                              0.30                                  NaN
# 423                              0.60                                  NaN
# ...                               ...                                  ...
# 134453                          22.99                                17.87
# 134454                          23.09                                17.93
# 134455                          23.29                                17.98
# 134457                          23.74                                18.07
# 134458                          24.02                                18.14
#
#         total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 364                            NaN                                    NaN
# 370                            NaN                                   34.0
# 386                            NaN                                   72.0
# 408                            NaN                                   75.0
# 423                            NaN                                  201.0
# ...                            ...                                    ...
# 134453                         NaN                                 1365.0
# 134454                         NaN                                 1476.0
# 134455                         NaN                                 1622.0
# 134457                         NaN                                 1976.0
# 134458                         NaN                                 2197.0
#
#         new_people_vaccinated_smoothed     location
# 364                                NaN  Afghanistan
# 370                             1367.0  Afghanistan
# 386                             2862.0  Afghanistan
# 408                             3000.0  Afghanistan
# 423                             8000.0  Afghanistan
# ...                                ...          ...
# 134453                         13782.0     Zimbabwe
# 134454                         14852.0     Zimbabwe
# 134455                         17188.0     Zimbabwe
# 134457                         22810.0     Zimbabwe
# 134458                         25915.0     Zimbabwe
#
# [32410 rows x 22 columns]

# %%
# Group data by 'people_vaccinated', and sort them in location
Order_people_vaccinations = vaccination.groupby('location').people_vaccinated.max()
Order_people_vaccinations= Order_people_vaccinations.sort_values(ascending=False)
Order_people_vaccinations= pd.DataFrame(Order_people_vaccinations)
Order_people_vaccinations.head(20)
# Out:
#                      people_vaccinated
# location
# World                     4.197512e+09
# Asia                      2.882381e+09
# Upper middle income       1.883448e+09
# Lower middle income       1.390193e+09
# China                     1.225000e+09
# High income               8.904829e+08
# India                     7.669880e+08
# Europe                    4.622119e+08
# North America             3.780404e+08
# European Union            3.131338e+08
# South America             3.102394e+08
# United States             2.302987e+08
# Brazil                    1.624368e+08
# Africa                    1.392699e+08
# Indonesia                 1.344183e+08
# Japan                     9.954649e+07
# Pakistan                  7.884517e+07
# Mexico                    7.586211e+07
# Vietnam                   6.670689e+07
# Russia                    6.349654e+07

# %%
# Calculate total vaccinations rate of first five countries
# There are too many name which are the general name for country, such as 'World','Lower Middle Income', 'Asia'
first_five_total_vacc = Order_people_vaccinations.iloc[[4,6,11,12,14,15,16,17,18],:]
first_five_total_vacc['location'] = first_five_total_vacc.index
first_five_total_vacc
# Out:
# /var/folders/ys/__80j13x36jdpb9j1fd0t3jr0000gn/T/ipykernel_841/4155894652.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_five_total_vacc['location'] = first_five_total_vacc.index
#                people_vaccinated       location
# location
# China               1.225000e+09          China
# India               7.669880e+08          India
# United States       2.302987e+08  United States
# Brazil              1.624368e+08         Brazil
# Indonesia           1.344183e+08      Indonesia
# Japan               9.954649e+07          Japan
# Pakistan            7.884517e+07       Pakistan
# Mexico              7.586211e+07         Mexico
# Vietnam             6.670689e+07        Vietnam

# %%
# Group data by 'people_vaccinated_per_hundred', and sort them in location
Order_fully_vaccinations_hundred = vaccination.groupby('location').people_vaccinated_per_hundred.max()
Order_fully_vaccinations_hundred= Order_fully_vaccinations_hundred.sort_values(ascending=False)
Order_fully_vaccinations_hundred= pd.DataFrame(Order_fully_vaccinations_hundred)
Order_fully_vaccinations_hundred.head(20)
# Out:
#                       people_vaccinated_per_hundred
# location
# Gibraltar                                    121.37
# Pitcairn                                     100.00
# United Arab Emirates                          98.10
# Singapore                                     92.99
# Brunei                                        90.56
# Cuba                                          89.47
# Portugal                                      89.04
# Chile                                         87.38
# Cayman Islands                                86.25
# China                                         84.82
# Malta                                         84.20
# Cambodia                                      83.15
# Iceland                                       82.87
# Seychelles                                    82.57
# South Korea                                   82.33
# Faeroe Islands                                81.96
# Spain                                         81.74
# Qatar                                         80.54
# Isle of Man                                   79.86
# Uruguay                                       79.65

# %%
# Top 5 countries of people vaccinated per hundred
Order_fully_vaccinations_hundred_top = Order_fully_vaccinations_hundred[1:6]
Order_fully_vaccinations_hundred_top
# Out:
#                       people_vaccinated_per_hundred
# location
# Pitcairn                                     100.00
# United Arab Emirates                          98.10
# Singapore                                     92.99
# Brunei                                        90.56
# Cuba                                          89.47

# %%
# Extract only three columns.
temp1=vaccination.loc[:,['location', 'date', 'people_fully_vaccinated_per_hundred']]
temp1
# Out:
#           location        date  people_fully_vaccinated_per_hundred
# 0      Afghanistan  2021-02-22                                  NaN
# 6      Afghanistan  2021-02-28                                  NaN
# 22     Afghanistan  2021-03-16                                  NaN
# 44     Afghanistan  2021-04-07                                  NaN
# 59     Afghanistan  2021-04-22                                  NaN
# ...            ...         ...                                  ...
# 63000     Zimbabwe  2021-11-16                                17.98
# 63002     Zimbabwe  2021-11-18                                18.07
# 63003     Zimbabwe  2021-11-19                                18.14
# 63004     Zimbabwe  2021-11-20                                18.18
# 63005     Zimbabwe  2021-11-21                                18.21
#
# [35729 rows x 3 columns]

# %%
temp1_Pitcairn=temp1[temp1.location == 'Pitcairn']
temp1_United_Arab_Emirates=temp1[temp1.location == 'United Arab Emirates']
temp1_Singapore=temp1[temp1.location == 'Singapore']
temp1_Brunei=temp1[temp1.location == 'Brunei']
temp1_Cuba=temp1[temp1.location == 'Cuba']

# %%
temp1_United_Arab_Emirates.sort_values(by = 'people_fully_vaccinated_per_hundred', ascending= True)
temp1_Pitcairn.sort_values(by = 'people_fully_vaccinated_per_hundred', ascending= True)
temp1_Singapore.sort_values(by = 'people_fully_vaccinated_per_hundred', ascending= True)
# Out:
#         location        date  people_fully_vaccinated_per_hundred
# 50584  Singapore  2021-01-27                                 0.00
# 50588  Singapore  2021-01-31                                 0.00
# 50590  Singapore  2021-02-02                                 0.11
# 50598  Singapore  2021-02-10                                 0.11
# 50606  Singapore  2021-02-18                                 2.02
# ...          ...         ...                                  ...
# 50820  Singapore  2021-09-20                                  NaN
# 50821  Singapore  2021-09-21                                  NaN
# 50822  Singapore  2021-09-22                                  NaN
# 50823  Singapore  2021-09-23                                  NaN
# 50824  Singapore  2021-09-24                                  NaN
#
# [124 rows x 3 columns]

# %%
# Temporary to delete the temp dataframe 0 value
temp1_United_Arab_Emirates=temp1_United_Arab_Emirates.drop(temp1_United_Arab_Emirates[temp1_United_Arab_Emirates.people_fully_vaccinated_per_hundred == 0].index)
temp1_Singapore=temp1_Singapore.drop(temp1_Singapore[temp1_Singapore.people_fully_vaccinated_per_hundred == 0].index)

# %%
# Group data by 'daily_vaccinations', and sort them in location
Order_daily_vaccinations= vaccination.groupby('location').daily_vaccinations.max()
Order_daily_vaccinations= Order_daily_vaccinations.sort_values(ascending=False)
Order_daily_vaccinations= pd.DataFrame(Order_daily_vaccinations)
Order_daily_vaccinations.head(20)
# Out:
#                      daily_vaccinations
# location
# World                        43233999.0
# Asia                         33335736.0
# Upper middle income          27439252.0
# China                        22424286.0
# Lower middle income          16674499.0
# India                        10037995.0
# High income                   8397153.0
# Europe                        5128678.0
# North America                 4173238.0
# European Union                4075834.0
# South America                 4055800.0
# United States                 3499189.0
# Brazil                        2595170.0
# Africa                        2030907.0
# Japan                         1997542.0
# Indonesia                     1901294.0
# Mexico                        1648223.0
# Vietnam                       1632517.0
# Bangladesh                    1502924.0
# Pakistan                      1280906.0

# %%
# There are too many name which are the general name for country, such as 'World','Lower Middle Income', 'Asia'
first_five_daily_vacc=Order_daily_vaccinations.iloc[[3,5,11,12,13,14,15,16,17,18],:]
first_five_daily_vacc['location'] = first_five_daily_vacc.index
first_five_daily_vacc
# Out:
# /var/folders/ys/__80j13x36jdpb9j1fd0t3jr0000gn/T/ipykernel_841/2424294992.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_five_daily_vacc['location'] = first_five_daily_vacc.index
#                daily_vaccinations       location
# location
# China                  22424286.0          China
# India                  10037995.0          India
# United States           3499189.0  United States
# Brazil                  2595170.0         Brazil
# Africa                  2030907.0         Africa
# Japan                   1997542.0          Japan
# Indonesia               1901294.0      Indonesia
# Mexico                  1648223.0         Mexico
# Vietnam                 1632517.0        Vietnam
# Bangladesh              1502924.0     Bangladesh

# %% [markdown]
# # Time Series: Arima Model

# %%
#Create new columns based on distinct values/ start of each new location and count them
vaccination_arima = vaccination.sort_values('location')
vaccination_arima['eid'] = (vaccination_arima.groupby(['location']).cumcount()==0).astype(int)

# Cumulatively sum the 'eid' column to assign a unique identifier to each location group
vaccination_arima['eid'] =vaccination_arima['eid'].cumsum()
vaccination_arima
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 265    Afghanistan      AFG  2021-11-14           4018197.0
# 220    Afghanistan      AFG  2021-09-30           2369625.0
# 190    Afghanistan      AFG  2021-08-31           1979652.0
# 179    Afghanistan      AFG  2021-08-20           1201286.0
# ...            ...      ...         ...                 ...
# 62827     Zimbabwe      ZWE  2021-05-27            953367.0
# 62828     Zimbabwe      ZWE  2021-05-28            976774.0
# 62829     Zimbabwe      ZWE  2021-05-29           1002443.0
# 62813     Zimbabwe      ZWE  2021-05-13            751998.0
# 63005     Zimbabwe      ZWE  2021-11-21           6419704.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                    0.0                      NaN             NaN
# 265            3530173.0                3188609.0             NaN
# 220             828601.0                      NaN             NaN
# 190             773002.0                      NaN             NaN
# 179             770542.0                 430744.0             NaN
# ...                  ...                      ...             ...
# 62827           648119.0                 305248.0             NaN
# 62828           656628.0                 320146.0             NaN
# 62829           666784.0                 335659.0             NaN
# 62813           559873.0                 192125.0             NaN
# 63005          3672011.0                2747693.0             NaN
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                 NaN
# 265                       NaN             36635.0
# 220                       NaN             12999.0
# 190                       NaN             70761.0
# 179                       NaN              1119.0
# ...                       ...                 ...
# 62827                 16349.0              9665.0
# 62828                 23407.0             10389.0
# 62829                 25669.0             13559.0
# 62813                 21655.0             20666.0
# 63005                 23692.0             36284.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                0.00                           0.00
# 265                             10.09                           8.86
# 220                              5.95                           2.08
# 190                              4.97                           1.94
# 179                              3.02                           1.93
# ...                               ...                            ...
# 62827                            6.32                           4.29
# 62828                            6.47                           4.35
# 62829                            6.64                           4.42
# 62813                            4.98                           3.71
# 63005                           42.54                          24.33
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                      NaN                         NaN
# 265                                   8.00                         NaN
# 220                                    NaN                         NaN
# 190                                    NaN                         NaN
# 179                                   1.08                         NaN
# ...                                    ...                         ...
# 62827                                 2.02                         NaN
# 62828                                 2.12                         NaN
# 62829                                 2.22                         NaN
# 62813                                 1.27                         NaN
# 63005                                18.21                         NaN
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# 0                                 NaN                      NaN
# 265                             920.0                  60035.0
# 220                             326.0                   1853.0
# 190                            1776.0                    224.0
# 179                              28.0                    690.0
# ...                               ...                      ...
# 62827                           640.0                   3614.0
# 62828                           688.0                   3755.0
# 62829                           898.0                   5052.0
# 62813                          1369.0                  11672.0
# 63005                          2404.0                  28973.0
#
#        daily_people_vaccinated_per_hundred  eid
# 0                                      NaN    1
# 265                                  0.151    1
# 220                                  0.005    1
# 190                                  0.001    1
# 179                                  0.002    1
# ...                                    ...  ...
# 62827                                0.024  235
# 62828                                0.025  235
# 62829                                0.033  235
# 62813                                0.077  235
# 63005                                0.192  235
#
# [35729 rows x 17 columns]

# %%
vaccination_arima[vaccination_arima.location == 'United States'].eid.unique()
# Out:
# array([223])

# %%
number_united_states = vaccination_arima.loc[vaccination_arima['eid']==223]

united_states = number_united_states.sort_values('people_vaccinated_per_hundred')

united_states
# Out:
#             location iso_code        date  total_vaccinations  \
# 59528  United States      USA  2020-12-13             21800.0
# 59529  United States      USA  2020-12-14             26124.0
# 59530  United States      USA  2020-12-15             74833.0
# 59531  United States      USA  2020-12-16            233645.0
# 59532  United States      USA  2020-12-17            504183.0
# ...              ...      ...         ...                 ...
# 59867  United States      USA  2021-11-17         449028238.0
# 59868  United States      USA  2021-11-18         450381454.0
# 59869  United States      USA  2021-11-19         451355421.0
# 59870  United States      USA  2021-11-20         451453834.0
# 59871  United States      USA  2021-11-21         451453834.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 59528            18529.0                   3875.0             NaN
# 59529            22716.0                   3971.0             NaN
# 59530            69226.0                   4166.0             NaN
# 59531           222604.0                   4548.0             NaN
# 59532           486107.0                   5110.0             NaN
# ...                  ...                      ...             ...
# 59867        229584222.0              194561634.0      33834775.0
# 59868        229972864.0              194694936.0      34677686.0
# 59869        230255670.0              194788580.0      35282993.0
# 59870        230298744.0              194797007.0      35329604.0
# 59871        230298744.0              194797007.0      35329604.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 59528                     NaN                 NaN
# 59529                  4324.0              4324.0
# 59530                 48709.0             26516.0
# 59531                158812.0             70615.0
# 59532                270538.0            120596.0
# ...                       ...                 ...
# 59867               1479995.0           1297921.0
# 59868               1353216.0           1288385.0
# 59869                973967.0           1174321.0
# 59870                 98413.0           1039368.0
# 59871                     0.0            964233.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 59528                            0.01                           0.01
# 59529                            0.01                           0.01
# 59530                            0.02                           0.02
# 59531                            0.07                           0.07
# 59532                            0.15                           0.14
# ...                               ...                            ...
# 59867                          133.51                          68.26
# 59868                          133.91                          68.38
# 59869                          134.20                          68.46
# 59870                          134.23                          68.48
# 59871                          134.23                          68.48
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 59528                                 0.00                         NaN
# 59529                                 0.00                         NaN
# 59530                                 0.00                         NaN
# 59531                                 0.00                         NaN
# 59532                                 0.00                         NaN
# ...                                    ...                         ...
# 59867                                57.85                       10.06
# 59868                                57.89                       10.31
# 59869                                57.92                       10.49
# 59870                                57.92                       10.50
# 59871                                57.92                       10.50
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# 59528                             NaN                      NaN
# 59529                            13.0                   4187.0
# 59530                            79.0                  25348.0
# 59531                           210.0                  68025.0
# 59532                           359.0                 116894.0
# ...                               ...                      ...
# 59867                          3859.0                 444416.0
# 59868                          3831.0                 427578.0
# 59869                          3492.0                 383614.0
# 59870                          3090.0                 321539.0
# 59871                          2867.0                 289854.0
#
#        daily_people_vaccinated_per_hundred  eid
# 59528                                  NaN  223
# 59529                                0.001  223
# 59530                                0.008  223
# 59531                                0.020  223
# 59532                                0.035  223
# ...                                    ...  ...
# 59867                                0.132  223
# 59868                                0.127  223
# 59869                                0.114  223
# 59870                                0.096  223
# 59871                                0.086  223
#
# [344 rows x 17 columns]

# %%
Value_united_states = united_states['people_vaccinated_per_hundred'].values
Value_united_states
# Out:
# array([1.000e-02, 1.000e-02, 2.000e-02, 7.000e-02, 1.400e-01, 2.600e-01,
#        3.200e-01, 3.500e-01, 4.600e-01, 5.900e-01, 7.600e-01, 8.100e-01,
#        8.200e-01, 8.600e-01, 8.900e-01, 1.060e+00, 1.270e+00, 1.510e+00,
#        1.630e+00, 1.660e+00, 1.730e+00, 1.770e+00, 1.950e+00, 2.160e+00,
#        2.410e+00, 2.660e+00, 2.910e+00, 3.020e+00, 3.080e+00, 3.290e+00,
#        3.560e+00, 3.870e+00, 4.210e+00, 4.550e+00, 4.720e+00, 4.790e+00,
#        4.980e+00, 5.270e+00, 5.620e+00, 6.020e+00, 6.440e+00, 6.660e+00,
#        6.750e+00, 7.000e+00, 7.320e+00, 7.690e+00, 8.100e+00, 8.500e+00,
#        8.730e+00, 8.830e+00, 9.060e+00, 9.340e+00, 9.720e+00, 1.013e+01,
#        1.054e+01, 1.079e+01, 1.087e+01, 1.112e+01, 1.143e+01, 1.180e+01,
#        1.218e+01, 1.259e+01, 1.284e+01, 1.295e+01, 1.313e+01, 1.337e+01,
#        1.365e+01, 1.390e+01, 1.414e+01, 1.432e+01, 1.440e+01, 1.459e+01,
#        1.485e+01, 1.523e+01, 1.569e+01, 1.619e+01, 1.653e+01, 1.669e+01,
#        1.705e+01, 1.749e+01, 1.801e+01, 1.859e+01, 1.919e+01, 1.959e+01,
#        1.979e+01, 2.024e+01, 2.078e+01, 2.139e+01, 2.207e+01, 2.271e+01,
#        2.312e+01, 2.332e+01, 2.376e+01, 2.434e+01, 2.497e+01, 2.566e+01,
#        2.632e+01, 2.675e+01, 2.695e+01, 2.743e+01, 2.802e+01, 2.868e+01,
#        2.936e+01, 2.999e+01, 3.040e+01, 3.061e+01, 3.109e+01, 3.169e+01,
#        3.241e+01, 3.316e+01, 3.378e+01, 3.417e+01, 3.430e+01, 3.482e+01,
#        3.550e+01, 3.627e+01, 3.703e+01, 3.776e+01, 3.828e+01, 3.852e+01,
#        3.901e+01, 3.953e+01, 4.005e+01, 4.058e+01, 4.107e+01, 4.142e+01,
#        4.158e+01, 4.190e+01, 4.232e+01, 4.273e+01, 4.315e+01, 4.356e+01,
#        4.386e+01, 4.401e+01, 4.429e+01, 4.462e+01, 4.497e+01, 4.530e+01,
#        4.563e+01, 4.584e+01, 4.594e+01, 4.613e+01, 4.638e+01, 4.662e+01,
#        4.685e+01, 4.709e+01, 4.724e+01, 4.731e+01, 4.745e+01, 4.765e+01,
#        4.785e+01, 4.812e+01, 4.845e+01, 4.872e+01, 4.886e+01, 4.913e+01,
#        4.943e+01, 4.972e+01, 5.000e+01, 5.027e+01, 5.049e+01, 5.059e+01,
#        5.078e+01, 5.098e+01, 5.118e+01, 5.136e+01, 5.154e+01, 5.166e+01,
#        5.172e+01, 5.174e+01, 5.190e+01, 5.205e+01, 5.219e+01, 5.234e+01,
#        5.244e+01, 5.249e+01, 5.260e+01, 5.273e+01, 5.284e+01, 5.296e+01,
#        5.309e+01, 5.318e+01, 5.321e+01, 5.331e+01, 5.342e+01, 5.352e+01,
#        5.363e+01, 5.374e+01, 5.381e+01, 5.384e+01, 5.393e+01, 5.403e+01,
#        5.413e+01, 5.422e+01, 5.433e+01, 5.439e+01, 5.443e+01, 5.451e+01,
#        5.460e+01, 5.469e+01, 5.478e+01, 5.487e+01, 5.493e+01, 5.493e+01,
#        5.499e+01, 5.508e+01, 5.516e+01, 5.525e+01, 5.534e+01, 5.540e+01,
#        5.544e+01, 5.552e+01, 5.560e+01, 5.569e+01, 5.578e+01, 5.588e+01,
#        5.595e+01, 5.599e+01, 5.609e+01, 5.620e+01, 5.631e+01, 5.644e+01,
#        5.658e+01, 5.667e+01, 5.673e+01, 5.686e+01, 5.700e+01, 5.715e+01,
#        5.730e+01, 5.747e+01, 5.757e+01, 5.763e+01, 5.778e+01, 5.794e+01,
#        5.810e+01, 5.827e+01, 5.845e+01, 5.857e+01, 5.864e+01, 5.879e+01,
#        5.895e+01, 5.909e+01, 5.925e+01, 5.942e+01, 5.953e+01, 5.959e+01,
#        5.973e+01, 5.987e+01, 6.002e+01, 6.016e+01, 6.032e+01, 6.041e+01,
#        6.047e+01, 6.060e+01, 6.074e+01, 6.087e+01, 6.102e+01, 6.117e+01,
#        6.127e+01, 6.133e+01, 6.145e+01, 6.157e+01, 6.170e+01, 6.182e+01,
#        6.195e+01, 6.203e+01, 6.208e+01, 6.210e+01, 6.220e+01, 6.231e+01,
#        6.242e+01, 6.256e+01, 6.263e+01, 6.268e+01, 6.278e+01, 6.287e+01,
#        6.296e+01, 6.306e+01, 6.316e+01, 6.322e+01, 6.326e+01, 6.334e+01,
#        6.341e+01, 6.349e+01, 6.357e+01, 6.366e+01, 6.372e+01, 6.376e+01,
#        6.385e+01, 6.394e+01, 6.403e+01, 6.412e+01, 6.422e+01, 6.427e+01,
#        6.430e+01, 6.438e+01, 6.446e+01, 6.453e+01, 6.461e+01, 6.470e+01,
#        6.474e+01, 6.477e+01, 6.484e+01, 6.491e+01, 6.498e+01, 6.505e+01,
#        6.513e+01, 6.517e+01, 6.520e+01, 6.527e+01, 6.533e+01, 6.539e+01,
#        6.546e+01, 6.555e+01, 6.560e+01, 6.564e+01, 6.574e+01, 6.583e+01,
#        6.593e+01, 6.603e+01, 6.613e+01, 6.619e+01, 6.622e+01, 6.631e+01,
#        6.640e+01, 6.650e+01, 6.661e+01, 6.674e+01, 6.684e+01, 6.690e+01,
#        6.703e+01, 6.718e+01, 6.734e+01, 6.749e+01, 6.766e+01, 6.781e+01,
#        6.787e+01, 6.800e+01, 6.813e+01, 6.826e+01, 6.838e+01, 6.846e+01,
#        6.848e+01, 6.848e+01])

# %%
print(f'\nThe ADFuller is {100*adfuller(Value_united_states)[1]:3.2f}%')
# Out:
# The ADFuller is 9.81%

# %%
plt.rcParams.update({'figure.figsize':(8,8),'figure.dpi':120})

# Original Series
fig,axes = plt.subplots(4,2,sharex= True)
axes[0,0].plot(Value_united_states)
axes[0,0].set_title('Original Series')
plot_acf(Value_united_states, ax= axes[0,1])

# First Order Differencing 
diffval = np.diff(Value_united_states)
axes[1,0].plot(diffval)
axes[1,0].set_title('1st Order Differencing')
plot_acf(diffval, ax= axes[1,1])

# Second Order Differencing
diffval1 = np.diff(diffval)
axes[2,0].plot(diffval1)
axes[2,0].set_title('2nd Order Differencing')
plot_acf(diffval1, ax= axes[2,1])

# Third Order Differencing
diffval2 = np.diff(diffval1)
axes[3,0].plot(diffval2)
axes[3,0].set_title('3rd Order Differencing')
plot_acf(diffval2, ax= axes[3,1])

plt.tight_layout()
plt.show()

# %%
model=pm.auto_arima(Value_united_states,start_p=1,start_q=1,
test='adf',
max_p=4, max_q=4,
m=1,
d=None,
seasonal=False,
start_P=0,
alpha=0.001,
D=0,
trace=True,
error_action='ignore',
suppress_warnings=True,
stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=-748.796, Time=0.17 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=-711.986, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=-717.905, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=-727.220, Time=0.05 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=-713.986, Time=0.01 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=-846.815, Time=0.11 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=-759.470, Time=0.03 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=-855.893, Time=0.13 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=-773.471, Time=0.06 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=-909.229, Time=0.25 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=-827.563, Time=0.08 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=-883.048, Time=0.22 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(4,2,1)(0,0,0)[0]             : AIC=-911.223, Time=0.07 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=-857.886, Time=0.07 sec
#  ARIMA(4,2,0)(0,0,0)[0]             : AIC=-829.563, Time=0.03 sec
#  ARIMA(4,2,2)(0,0,0)[0]             : AIC=-885.429, Time=0.15 sec
#  ARIMA(3,2,0)(0,0,0)[0]             : AIC=-775.471, Time=0.03 sec
#  ARIMA(3,2,2)(0,0,0)[0]             : AIC=-948.485, Time=0.17 sec
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=-944.283, Time=0.10 sec
#  ARIMA(3,2,3)(0,0,0)[0]             : AIC=-957.329, Time=0.13 sec
#  ARIMA(2,2,3)(0,0,0)[0]             : AIC=-970.357, Time=0.12 sec
#  ARIMA(1,2,3)(0,0,0)[0]             : AIC=-848.580, Time=0.09 sec
#  ARIMA(2,2,4)(0,0,0)[0]             : AIC=-895.887, Time=0.32 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,2,4)(0,0,0)[0]             : AIC=-892.544, Time=0.19 sec
#  ARIMA(3,2,4)(0,0,0)[0]             : AIC=-1001.364, Time=0.27 sec
#  ARIMA(4,2,4)(0,0,0)[0]             : AIC=-1112.530, Time=0.29 sec
#  ARIMA(4,2,3)(0,0,0)[0]             : AIC=-1058.647, Time=0.24 sec
#  ARIMA(4,2,4)(0,0,0)[0] intercept   : AIC=-1027.488, Time=0.38 sec
#
# Best model:  ARIMA(4,2,4)(0,0,0)[0]
# Total fit time: 4.228 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  344
# Model:               SARIMAX(4, 2, 4)   Log Likelihood                 565.265
# Date:                Tue, 09 Jul 2024   AIC                          -1112.530
# Time:                        00:34:28   BIC                          -1078.016
# Sample:                             0   HQIC                         -1098.781
#                                 - 344
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8304      0.014     57.765      0.000       0.802       0.859
# ar.L2         -1.4344      0.014   -103.671      0.000      -1.461      -1.407
# ar.L3          0.8217      0.016     51.341      0.000       0.790       0.853
# ar.L4         -0.9533      0.011    -84.785      0.000      -0.975      -0.931
# ma.L1         -1.0277      0.039    -26.426      0.000      -1.104      -0.951
# ma.L2          1.2979      0.044     29.536      0.000       1.212       1.384
# ma.L3         -0.9817      0.039    -25.101      0.000      -1.058      -0.905
# ma.L4          0.7221      0.037     19.368      0.000       0.649       0.795
# sigma2         0.0021      0.000     19.027      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.67   Jarque-Bera (JB):                94.78
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.12   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## WE choose the model arima (4,2,4)

# %%
# Forecase 
n_periods = 50

# predict model 
fc,confint = model.predict(n_periods = n_periods, return_conf_int = True, alpha = 0.5)
index_of_fc = np.arange(len(Value_united_states),len(Value_united_states)+n_periods)


fc_series = pd.Series(fc,index = index_of_fc)
lower_series = pd.Series(confint[:,0],index = index_of_fc)
upper_series = pd.Series(confint[:,1],index = index_of_fc)

# PLot
plt.plot(Value_united_states)
plt.plot(fc_series, color = 'orange')
plt.fill_between(lower_series.index,lower_series,upper_series,color = 'red',alpha = 0.15)
plt.show()

# %%
# Get the final day's people_vaccinated_per_hundred

final_day_vacc_rate_US = Value_united_states[-1]/100
final_day_vacc_rate_US
# Out:
# 0.6848000000000001

# %%
#  Get the population of the United States 
united_states_population = float(covid[covid.location == 'United States'].population.unique())
print('The population of the US is', float(united_states_population))
# Out:
# The population of the US is 332915074.0
# /var/folders/ys/__80j13x36jdpb9j1fd0t3jr0000gn/T/ipykernel_841/3360495347.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   united_states_population = float(covid[covid.location == 'United States'].population.unique())

# %%
base_case_US = fc_series/100 -final_day_vacc_rate_US
base_case_total_US = fc_series/100
base_case_increase_US = base_case_US * united_states_population
base_case_num_of_total_US = base_case_total_US * united_states_population


base_case_summary_df = pd.concat([base_case_increase_US,base_case_num_of_total_US],axis = 1)
base_case_summary_df.columns = ['Base Case of Number of vaccinated rate in 100 days (only in these 100 days)','Base Case of total vaccinated rate from the beggining to the next 100 days']
base_case_summary_df = base_case_summary_df.reset_index().iloc[:,1:]
base_case_summary_df
# Out:
#     Base Case of Number of vaccinated rate in 100 days (only in these 100 days)  \
# 0                                        1.805158e+05
# 1                                        4.729835e+05
# 2                                        7.070118e+05
# 3                                        9.171322e+05
# 4                                        1.111116e+06
# 5                                        1.171247e+06
# 6                                        1.179441e+06
# 7                                        1.346034e+06
# 8                                        1.624062e+06
# 9                                        1.852358e+06
# 10                                       2.059178e+06
# 11                                       2.260053e+06
# 12                                       2.339696e+06
# 13                                       2.356962e+06
# 14                                       2.511908e+06
# 15                                       2.776717e+06
# 16                                       2.999591e+06
# 17                                       3.202654e+06
# 18                                       3.408426e+06
# 19                                       3.505673e+06
# 20                                       3.532614e+06
# 21                                       3.677951e+06
# 22                                       3.930696e+06
# 23                                       4.148504e+06
# 24                                       4.347544e+06
# 25                                       4.556491e+06
# 26                                       4.669483e+06
# 27                                       4.706470e+06
# 28                                       4.844007e+06
# 29                                       5.085777e+06
# 30                                       5.298903e+06
# 31                                       5.493811e+06
# 32                                       5.704461e+06
# 33                                       5.831410e+06
# 34                                       5.878612e+06
# 35                                       6.009952e+06
# 36                                       6.241768e+06
# 37                                       6.450603e+06
# 38                                       6.641397e+06
# 39                                       6.852513e+06
# 40                                       6.991715e+06
# 41                                       7.049134e+06
# 42                                       7.175687e+06
# 43                                       7.398497e+06
# 44                                       7.603433e+06
# 45                                       7.790234e+06
# 46                                       8.000790e+06
# 47                                       8.150638e+06
# 48                                       8.218135e+06
# 49                                       8.341135e+06
#
#     Base Case of total vaccinated rate from the beggining to the next 100 days
# 0                                        2.281608e+08
# 1                                        2.284532e+08
# 2                                        2.286873e+08
# 3                                        2.288974e+08
# 4                                        2.290914e+08
# 5                                        2.291515e+08
# 6                                        2.291597e+08
# 7                                        2.293263e+08
# 8                                        2.296043e+08
# 9                                        2.298326e+08
# 10                                       2.300394e+08
# 11                                       2.302403e+08
# 12                                       2.303199e+08
# 13                                       2.303372e+08
# 14                                       2.304922e+08
# 15                                       2.307570e+08
# 16                                       2.309798e+08
# 17                                       2.311829e+08
# 18                                       2.313887e+08
# 19                                       2.314859e+08
# 20                                       2.315129e+08
# 21                                       2.316582e+08
# 22                                       2.319109e+08
# 23                                       2.321287e+08
# 24                                       2.323278e+08
# 25                                       2.325367e+08
# 26                                       2.326497e+08
# 27                                       2.326867e+08
# 28                                       2.328243e+08
# 29                                       2.330660e+08
# 30                                       2.332791e+08
# 31                                       2.334741e+08
# 32                                       2.336847e+08
# 33                                       2.338117e+08
# 34                                       2.338589e+08
# 35                                       2.339902e+08
# 36                                       2.342220e+08
# 37                                       2.344308e+08
# 38                                       2.346216e+08
# 39                                       2.348328e+08
# 40                                       2.349720e+08
# 41                                       2.350294e+08
# 42                                       2.351559e+08
# 43                                       2.353787e+08
# 44                                       2.355837e+08
# 45                                       2.357705e+08
# 46                                       2.359810e+08
# 47                                       2.361309e+08
# 48                                       2.361984e+08
# 49                                       2.363214e+08

# %% [markdown]
# ***Base-Case Scenario:*** shows that we forecast that the number of people vaccinates (left-side column)in the next 50 days is increased from the first day (282622 people get vaccinated) to the final day (1806515 people get vaccinated in these 50 days. JUST IN THESE 50 DAYS), in other words, the from now on to the next 50 days, there will 8341135 people get vaccinated
# This base-case scenario data frame (right-side column) shows that the predicted total number of people who get vaccinated from the very beginning until the next 50 days is 236321400 for the whole period from the very beginning to the next 50 days.

# %%
#lower_series --- worst case

worst_case = lower_series/100 - final_day_vacc_rate_US
worst_case_total = lower_series/100
worst_case_increase_num = worst_case* united_states_population
worst_case_num_total = worst_case_total* united_states_population
worst_case_summary_df = pd.concat([worst_case_increase_num, worst_case_num_total],axis=1)
worst_case_summary_df.columns = ['Worst Case of Number of vaccinated rate in 50 days (only in these 50 days)','Worst Case of Total Vaccinated rate from begining to the next 50 days']
worst_case_summary_df = worst_case_summary_df.reset_index().iloc[:,1:]
worst_case_summary_df
# Out:
#     Worst Case of Number of vaccinated rate in 50 days (only in these 50 days)  \
# 0                                        7.840898e+04
# 1                                        2.624903e+05
# 2                                        3.912462e+05
# 3                                        4.992102e+05
# 4                                        5.935762e+05
# 5                                        5.500562e+05
# 6                                        4.318166e+05
# 7                                        4.389201e+05
# 8                                        5.389081e+05
# 9                                        5.876273e+05
# 10                                       6.177567e+05
# 11                                       6.460997e+05
# 12                                       5.539427e+05
# 13                                       3.866989e+05
# 14                                       3.348793e+05
# 15                                       3.778775e+05
# 16                                       3.754727e+05
# 17                                       3.539340e+05
# 18                                       3.377604e+05
# 19                                       2.143992e+05
# 20                                       1.220623e+04
# 21                                      -8.848310e+04
# 22                                      -9.443233e+04
# 23                                      -1.393569e+05
# 24                                      -2.035956e+05
# 25                                      -2.564643e+05
# 26                                      -4.039924e+05
# 27                                      -6.336794e+05
# 28                                      -7.763217e+05
# 29                                      -8.257087e+05
# 30                                      -9.079751e+05
# 31                                      -1.009762e+06
# 32                                      -1.095245e+06
# 33                                      -1.263356e+06
# 34                                      -1.515840e+06
# 35                                      -1.695305e+06
# 36                                      -1.783980e+06
# 37                                      -1.899912e+06
# 38                                      -2.035684e+06
# 39                                      -2.151268e+06
# 40                                      -2.337973e+06
# 41                                      -2.610042e+06
# 42                                      -2.822304e+06
# 43                                      -2.946959e+06
# 44                                      -3.093726e+06
# 45                                      -3.260763e+06
# 46                                      -3.404720e+06
# 47                                      -3.608888e+06
# 48                                      -3.898248e+06
# 49                                      -4.140037e+06
#
#     Worst Case of Total Vaccinated rate from begining to the next 50 days
# 0                                        2.280587e+08
# 1                                        2.282427e+08
# 2                                        2.283715e+08
# 3                                        2.284795e+08
# 4                                        2.285738e+08
# 5                                        2.285303e+08
# 6                                        2.284121e+08
# 7                                        2.284192e+08
# 8                                        2.285192e+08
# 9                                        2.285679e+08
# 10                                       2.285980e+08
# 11                                       2.286263e+08
# 12                                       2.285342e+08
# 13                                       2.283669e+08
# 14                                       2.283151e+08
# 15                                       2.283581e+08
# 16                                       2.283557e+08
# 17                                       2.283342e+08
# 18                                       2.283180e+08
# 19                                       2.281946e+08
# 20                                       2.279924e+08
# 21                                       2.278918e+08
# 22                                       2.278858e+08
# 23                                       2.278409e+08
# 24                                       2.277766e+08
# 25                                       2.277238e+08
# 26                                       2.275763e+08
# 27                                       2.273466e+08
# 28                                       2.272039e+08
# 29                                       2.271545e+08
# 30                                       2.270723e+08
# 31                                       2.269705e+08
# 32                                       2.268850e+08
# 33                                       2.267169e+08
# 34                                       2.264644e+08
# 35                                       2.262849e+08
# 36                                       2.261963e+08
# 37                                       2.260803e+08
# 38                                       2.259446e+08
# 39                                       2.258290e+08
# 40                                       2.256423e+08
# 41                                       2.253702e+08
# 42                                       2.251579e+08
# 43                                       2.250333e+08
# 44                                       2.248865e+08
# 45                                       2.247195e+08
# 46                                       2.245755e+08
# 47                                       2.243714e+08
# 48                                       2.240820e+08
# 49                                       2.238402e+08

# %% [markdown]
# ***Worst-Case Scenario:*** which shows that we forecast that the number of people vaccinate (left-side column)in next 50 days changed from the first day (78409 people get vaccinated) to 21th day(0 people vaccinated lasted to the final day). In other words, the from now on to the next 50 days, there will 0 people get vaccinated.
#
#  This worst-case scenario dataframe (right-side column) shows that the predict total number of people get vaccinated from the very begining which is 228058700 unitil the next 50 days is 227992400 for the whole time period from very beginning to the next 50 days.

# %%
best_case=upper_series/100-final_day_vacc_rate_US
best_case_total=upper_series/100
best_case_increase_num=best_case* united_states_population
best_case_num_total=best_case_total* united_states_population
best_case_summary_df = pd.concat([best_case_increase_num,best_case_num_total],axis=1)
best_case_summary_df.columns=['Best Case of Number of vaccinated rate in 50 days (only in these 50 days)','Best Case of Total Vaccinated rate from begining to the next 50 days']
best_case_summary_df=best_case_summary_df.reset_index().iloc[:,1:]
best_case_summary_df
# Out:
#     Best Case of Number of vaccinated rate in 50 days (only in these 50 days)  \
# 0                                        2.826226e+05
# 1                                        6.834767e+05
# 2                                        1.022777e+06
# 3                                        1.335054e+06
# 4                                        1.628656e+06
# 5                                        1.792438e+06
# 6                                        1.927066e+06
# 7                                        2.253147e+06
# 8                                        2.709216e+06
# 9                                        3.117088e+06
# 10                                       3.500599e+06
# 11                                       3.874006e+06
# 12                                       4.125449e+06
# 13                                       4.327224e+06
# 14                                       4.688938e+06
# 15                                       5.175556e+06
# 16                                       5.623708e+06
# 17                                       6.051374e+06
# 18                                       6.479091e+06
# 19                                       6.796946e+06
# 20                                       7.053022e+06
# 21                                       7.444386e+06
# 22                                       7.955824e+06
# 23                                       8.436365e+06
# 24                                       8.898684e+06
# 25                                       9.369445e+06
# 26                                       9.742958e+06
# 27                                       1.004662e+07
# 28                                       1.046434e+07
# 29                                       1.099726e+07
# 30                                       1.150578e+07
# 31                                       1.199738e+07
# 32                                       1.250417e+07
# 33                                       1.292618e+07
# 34                                       1.327306e+07
# 35                                       1.371521e+07
# 36                                       1.426752e+07
# 37                                       1.480112e+07
# 38                                       1.531848e+07
# 39                                       1.585629e+07
# 40                                       1.632140e+07
# 41                                       1.670831e+07
# 42                                       1.717368e+07
# 43                                       1.774395e+07
# 44                                       1.830059e+07
# 45                                       1.884123e+07
# 46                                       1.940630e+07
# 47                                       1.991016e+07
# 48                                       2.033452e+07
# 49                                       2.082231e+07
#
#     Best Case of Total Vaccinated rate from begining to the next 50 days
# 0                                        2.282629e+08
# 1                                        2.286637e+08
# 2                                        2.290030e+08
# 3                                        2.293153e+08
# 4                                        2.296089e+08
# 5                                        2.297727e+08
# 6                                        2.299073e+08
# 7                                        2.302334e+08
# 8                                        2.306895e+08
# 9                                        2.310973e+08
# 10                                       2.314808e+08
# 11                                       2.318542e+08
# 12                                       2.321057e+08
# 13                                       2.323075e+08
# 14                                       2.326692e+08
# 15                                       2.331558e+08
# 16                                       2.336040e+08
# 17                                       2.340316e+08
# 18                                       2.344593e+08
# 19                                       2.347772e+08
# 20                                       2.350333e+08
# 21                                       2.354246e+08
# 22                                       2.359361e+08
# 23                                       2.364166e+08
# 24                                       2.368789e+08
# 25                                       2.373497e+08
# 26                                       2.377232e+08
# 27                                       2.380269e+08
# 28                                       2.384446e+08
# 29                                       2.389775e+08
# 30                                       2.394860e+08
# 31                                       2.399776e+08
# 32                                       2.404844e+08
# 33                                       2.409064e+08
# 34                                       2.412533e+08
# 35                                       2.416955e+08
# 36                                       2.422478e+08
# 37                                       2.427814e+08
# 38                                       2.432987e+08
# 39                                       2.438365e+08
# 40                                       2.443016e+08
# 41                                       2.446886e+08
# 42                                       2.451539e+08
# 43                                       2.457242e+08
# 44                                       2.462808e+08
# 45                                       2.468215e+08
# 46                                       2.473865e+08
# 47                                       2.478904e+08
# 48                                       2.483148e+08
# 49                                       2.488025e+08

# %% [markdown]
# ***Best-Case Scenario:*** shows that we forecast that the number of people vaccinates (left-side column)in the next 50 days is increased from the first day (282622 people get vaccinated) to the final day (2318170 people get vaccinated in these 50 days. JUST IN THESE 50 DAYS), in other words, the from now on to the next 50 days, there will 20822310 people get vaccinated
# This best-case scenario data frame (right-side column) shows that the predicted total number of people who get vaccinated from the very beginning until the next 50 days is 248802500 for the whole period from the very beginning to the next 50 days.

# %% [markdown]
# # Canada case

# %%
number_canada = vaccination_arima.loc[vaccination_arima['eid']==38]

canada = number_canada.sort_values('people_vaccinated_per_hundred')

# %%
value_canada = canada['people_vaccinated_per_hundred'].values
value_canada
# Out:
# array([0.000e+00, 0.000e+00, 1.000e-02, 2.000e-02, 3.000e-02, 3.000e-02,
#        3.000e-02, 6.000e-02, 7.000e-02, 9.000e-02, 1.200e-01, 1.300e-01,
#        1.300e-01, 1.400e-01, 1.500e-01, 1.900e-01, 2.300e-01, 2.600e-01,
#        2.800e-01, 2.900e-01, 3.000e-01, 3.600e-01, 4.100e-01, 4.800e-01,
#        5.800e-01, 6.900e-01, 7.800e-01, 8.400e-01, 9.400e-01, 1.020e+00,
#        1.080e+00, 1.180e+00, 1.300e+00, 1.390e+00, 1.460e+00, 1.570e+00,
#        1.670e+00, 1.750e+00, 1.850e+00, 1.930e+00, 1.990e+00, 2.020e+00,
#        2.060e+00, 2.120e+00, 2.150e+00, 2.190e+00, 2.220e+00, 2.240e+00,
#        2.250e+00, 2.290e+00, 2.310e+00, 2.320e+00, 2.340e+00, 2.360e+00,
#        2.380e+00, 2.400e+00, 2.430e+00, 2.450e+00, 2.480e+00, 2.510e+00,
#        2.550e+00, 2.580e+00, 2.590e+00, 2.590e+00, 2.610e+00, 2.630e+00,
#        2.650e+00, 2.710e+00, 2.800e+00, 2.880e+00, 2.960e+00, 3.040e+00,
#        3.120e+00, 3.230e+00, 3.380e+00, 3.520e+00, 3.630e+00, 3.750e+00,
#        3.920e+00, 4.100e+00, 4.290e+00, 4.510e+00, 4.700e+00, 4.840e+00,
#        5.040e+00, 5.220e+00, 5.410e+00, 5.660e+00, 5.950e+00, 6.220e+00,
#        6.460e+00, 6.770e+00, 7.080e+00, 7.430e+00, 7.830e+00, 8.240e+00,
#        8.580e+00, 8.810e+00, 9.190e+00, 9.500e+00, 9.940e+00, 1.043e+01,
#        1.098e+01, 1.140e+01, 1.178e+01, 1.225e+01, 1.268e+01, 1.324e+01,
#        1.376e+01, 1.417e+01, 1.469e+01, 1.499e+01, 1.543e+01, 1.594e+01,
#        1.650e+01, 1.714e+01, 1.793e+01, 1.853e+01, 1.900e+01, 1.983e+01,
#        2.051e+01, 2.126e+01, 2.202e+01, 2.285e+01, 2.345e+01, 2.397e+01,
#        2.461e+01, 2.520e+01, 2.600e+01, 2.692e+01, 2.784e+01, 2.856e+01,
#        2.914e+01, 2.981e+01, 3.044e+01, 3.109e+01, 3.184e+01, 3.256e+01,
#        3.312e+01, 3.355e+01, 3.412e+01, 3.469e+01, 3.539e+01, 3.627e+01,
#        3.726e+01, 3.808e+01, 3.877e+01, 3.960e+01, 4.034e+01, 4.120e+01,
#        4.216e+01, 4.323e+01, 4.412e+01, 4.492e+01, 4.591e+01, 4.658e+01,
#        4.743e+01, 4.836e+01, 4.951e+01, 5.041e+01, 5.116e+01, 5.204e+01,
#        5.266e+01, 5.333e+01, 5.423e+01, 5.527e+01, 5.599e+01, 5.666e+01,
#        5.751e+01, 5.812e+01, 5.876e+01, 5.948e+01, 6.025e+01, 6.087e+01,
#        6.138e+01, 6.205e+01, 6.248e+01, 6.292e+01, 6.338e+01, 6.383e+01,
#        6.417e+01, 6.448e+01, 6.482e+01, 6.513e+01, 6.539e+01, 6.566e+01,
#        6.591e+01, 6.609e+01, 6.625e+01, 6.646e+01, 6.663e+01, 6.678e+01,
#        6.696e+01, 6.712e+01, 6.723e+01, 6.734e+01, 6.756e+01, 6.771e+01,
#        6.785e+01, 6.795e+01, 6.811e+01, 6.819e+01, 6.827e+01, 6.842e+01,
#        6.854e+01, 6.865e+01, 6.881e+01, 6.894e+01, 6.903e+01, 6.910e+01,
#        6.924e+01, 6.934e+01, 6.946e+01, 6.958e+01, 6.970e+01, 6.979e+01,
#        6.985e+01, 6.996e+01, 7.006e+01, 7.016e+01, 7.027e+01, 7.038e+01,
#        7.046e+01, 7.053e+01, 7.063e+01, 7.073e+01, 7.083e+01, 7.093e+01,
#        7.104e+01, 7.110e+01, 7.115e+01, 7.118e+01, 7.130e+01, 7.137e+01,
#        7.146e+01, 7.155e+01, 7.161e+01, 7.165e+01, 7.174e+01, 7.181e+01,
#        7.188e+01, 7.196e+01, 7.205e+01, 7.211e+01, 7.216e+01, 7.225e+01,
#        7.233e+01, 7.240e+01, 7.250e+01, 7.259e+01, 7.266e+01, 7.270e+01,
#        7.279e+01, 7.287e+01, 7.296e+01, 7.307e+01, 7.317e+01, 7.323e+01,
#        7.328e+01, 7.340e+01, 7.347e+01, 7.356e+01, 7.366e+01, 7.379e+01,
#        7.387e+01, 7.393e+01, 7.396e+01, 7.409e+01, 7.418e+01, 7.429e+01,
#        7.440e+01, 7.447e+01, 7.452e+01, 7.464e+01, 7.473e+01, 7.482e+01,
#        7.493e+01, 7.507e+01, 7.514e+01, 7.519e+01, 7.537e+01, 7.548e+01,
#        7.560e+01, 7.573e+01, 7.586e+01, 7.593e+01, 7.599e+01, 7.613e+01,
#        7.621e+01, 7.632e+01, 7.642e+01, 7.650e+01, 7.655e+01, 7.659e+01,
#        7.670e+01, 7.678e+01, 7.689e+01, 7.697e+01, 7.707e+01, 7.712e+01,
#        7.717e+01, 7.720e+01, 7.732e+01, 7.737e+01, 7.745e+01, 7.755e+01,
#        7.759e+01, 7.763e+01, 7.771e+01, 7.777e+01, 7.784e+01, 7.791e+01,
#        7.798e+01, 7.801e+01, 7.805e+01, 7.811e+01, 7.817e+01, 7.822e+01,
#        7.828e+01, 7.835e+01, 7.838e+01, 7.840e+01, 7.845e+01, 7.847e+01,
#        7.852e+01, 7.857e+01, 7.862e+01, 7.863e+01, 7.866e+01, 7.872e+01,
#        7.874e+01, 7.881e+01, 7.884e+01, 7.889e+01, 7.892e+01, 7.894e+01,
#        7.899e+01, 7.902e+01, 7.908e+01, 7.913e+01, 7.916e+01, 7.919e+01,
#        7.921e+01])

# %%
print(f'\nThe ADFuller is {100*adfuller(value_canada)[1]:3.2f}%')
# Out:
# The ADFuller is 51.96%

# %%
plt.rcParams.update({'figure.figsize':(7,7),'figure.dpi':120})

#original Series
fig, axes = plt.subplots(4,2,sharex=True)
axes[0,0].plot(value_canada); axes[0,0].set_title('original Series')
plot_acf(value_canada,ax=axes[0,1])

# 1st Differencing
axes[1,0].plot(np.diff(value_canada));axes[1,0].set_title('1st Oder Differecing')
plot_acf(np.diff(value_canada),ax=axes[1,1])
diffval=np.diff(value_canada)


# 2st Differencing
axes[2,0].plot(np.diff(value_canada));axes[2,0].set_title('2st Oder Differecing')
plot_acf(np.diff(diffval),ax=axes[2,1])
diffva2=np.diff(diffval)


# 3st Differencing
axes[3,0].plot(np.diff(value_canada));axes[3,0].set_title('3st Oder Differecing')
plot_acf(np.diff(diffva2),ax=axes[3,1])
diffv3=np.diff(diffva2)

plt.show()

# %%
model1 = pm.auto_arima(value_canada,start_p = 1, start_q = 1,
    test = 'adf',
    max_p = 4, max_q = 4,
    d = None,
    seasonal = False,
    start_P = 0,
    D = 0,
    alpha = 0.001,
    trace = True,
    error_action = 'ignore',
    suppress_warnings = True,
    stepwise = True
)

print(model1.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=-827.550, Time=0.15 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=-774.375, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=-794.401, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=-817.567, Time=0.04 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=-776.375, Time=0.01 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=-829.741, Time=0.07 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=-818.651, Time=0.03 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=-827.765, Time=0.12 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=-827.927, Time=0.09 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=-829.936, Time=0.07 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=-831.341, Time=0.06 sec
#  ARIMA(0,2,3)(0,0,0)[0] intercept   : AIC=-829.977, Time=0.11 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=-834.738, Time=0.22 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=-856.348, Time=0.22 sec
#  ARIMA(3,2,3)(0,0,0)[0] intercept   : AIC=-891.961, Time=0.26 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=-827.994, Time=0.23 sec
#  ARIMA(4,2,3)(0,0,0)[0] intercept   : AIC=-822.159, Time=0.24 sec
#  ARIMA(3,2,4)(0,0,0)[0] intercept   : AIC=-864.753, Time=0.40 sec
#  ARIMA(2,2,4)(0,0,0)[0] intercept   : AIC=-870.083, Time=0.34 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=-824.717, Time=0.29 sec
#  ARIMA(4,2,4)(0,0,0)[0] intercept   : AIC=-880.733, Time=0.43 sec
#  ARIMA(3,2,3)(0,0,0)[0]             : AIC=-892.059, Time=0.19 sec
#  ARIMA(2,2,3)(0,0,0)[0]             : AIC=-867.769, Time=0.19 sec
#  ARIMA(3,2,2)(0,0,0)[0]             : AIC=-835.043, Time=0.13 sec
#  ARIMA(4,2,3)(0,0,0)[0]             : AIC=-886.830, Time=0.17 sec
#  ARIMA(3,2,4)(0,0,0)[0]             : AIC=-866.780, Time=0.19 sec
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=-829.925, Time=0.07 sec
#  ARIMA(2,2,4)(0,0,0)[0]             : AIC=-882.529, Time=0.18 sec
#  ARIMA(4,2,2)(0,0,0)[0]             : AIC=-899.987, Time=0.19 sec
#  ARIMA(4,2,1)(0,0,0)[0]             : AIC=-833.382, Time=0.08 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=-829.763, Time=0.06 sec
#
# Best model:  ARIMA(4,2,2)(0,0,0)[0]
# Total fit time: 4.871 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  343
# Model:               SARIMAX(4, 2, 2)   Log Likelihood                 456.994
# Date:                Tue, 09 Jul 2024   AIC                           -899.987
# Time:                        00:34:34   BIC                           -873.164
# Sample:                             0   HQIC                          -889.300
#                                 - 343
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5680      0.062      9.132      0.000       0.446       0.690
# ar.L2         -0.5071      0.055     -9.272      0.000      -0.614      -0.400
# ar.L3         -0.0729      0.049     -1.484      0.138      -0.169       0.023
# ar.L4         -0.3823      0.043     -8.944      0.000      -0.466      -0.299
# ma.L1         -1.1795      0.063    -18.752      0.000      -1.303      -1.056
# ma.L2          0.7379      0.066     11.227      0.000       0.609       0.867
# sigma2         0.0042      0.000     16.765      0.000       0.004       0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.45   Jarque-Bera (JB):               214.40
# Prob(Q):                              0.23   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.39   Skew:                             0.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## WE choose the model arima (4,2,2)

# %%
# Forecase
n_periods= 50
# predict model
fc, confint = model1.predict(n_periods=n_periods,return_conf_int=True, alpha=0.5)
index_of_fc=np.arange(len(value_canada),len(value_canada)+n_periods)

fc_series = pd.Series(fc, index=index_of_fc)
lower_series=pd.Series(confint[:,0],index=index_of_fc)
upper_series=pd.Series(confint[:,1],index=index_of_fc)

#Plot
plt.plot(value_canada)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, lower_series, upper_series,color='b',alpha=.15)
plt.show()

# %%
# get the final day's people_vaccinated_per_hundred
final_day_vacc_rate=value_canada[-1]/100
final_day_vacc_rate
# Out:
# 0.7920999999999999

# %%
# Get the population of the Canada
canada_population=float(covid[covid.location =='Canada'].population.unique())
print ('The Population of Canada is',float(covid[covid.location =='Canada'].population.unique()))
# Out:
# The Population of Canada is 38067913.0
# The Population of UK is 68207114.0
# /var/folders/ys/__80j13x36jdpb9j1fd0t3jr0000gn/T/ipykernel_841/3790732036.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   canada_population=float(covid[covid.location =='Canada'].population.unique())
# /var/folders/ys/__80j13x36jdpb9j1fd0t3jr0000gn/T/ipykernel_841/3790732036.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print ('The Population of Canada is',float(covid[covid.location =='Canada'].population.unique()))
# /var/folders/ys/__80j13x36jdpb9j1fd0t3jr0000gn/T/ipykernel_841/3790732036.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   UK_population=float(covid[covid.location =='United Kingdom'].population.unique())
# /var/folders/ys/__80j13x36jdpb9j1fd0t3jr0000gn/T/ipykernel_841/3790732036.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print ('The Population of UK is',float(covid[covid.location =='United Kingdom'].population.unique()))

# %%
# forecast the base case of the increase number of people vaccinated per hundard rate in 50 days
base_case = fc_series/100-final_day_vacc_rate
base_case_total = fc_series/100
base_case_increase_num=base_case*canada_population
base_case_num_total=base_case_total*canada_population

base_case_summary_df = pd.concat([base_case_increase_num,base_case_num_total],axis=1)
base_case_summary_df.columns=['Base Case of Number of vaccinated rate in 50 days (only in these 50 days)','Base Case of Total Vaccinated rate from begining to the next 50 days']
base_case_summary_df = base_case_summary_df.reset_index().iloc[:,1:]
base_case_summary_df
# Out:
#     Base Case of Number of vaccinated rate in 50 days (only in these 50 days)  \
# 0                                        10516.911136
# 1                                        24137.326584
# 2                                        38325.718842
# 3                                        52506.435638
# 4                                        65058.549864
# 5                                        75461.665102
# 6                                        85253.502426
# 7                                        95909.645934
# 8                                       108146.001947
# 9                                       121707.706214
# 10                                      135391.491096
# 11                                      148026.854619
# 12                                      159304.071799
# 13                                      169825.987020
# 14                                      180637.428501
# 15                                      192496.187053
# 16                                      205377.267341
# 17                                      218575.527586
# 18                                      231248.444929
# 19                                      242987.196731
# 20                                      254047.814397
# 21                                      265114.050514
# 22                                      276796.329010
# 23                                      289232.235568
# 24                                      302042.618979
# 25                                      314636.448355
# 26                                      326626.909499
# 27                                      338069.072336
# 28                                      349378.422669
# 29                                      361017.176469
# 30                                      373181.024031
# 31                                      385695.364426
# 32                                      398169.245944
# 33                                      410278.186236
# 34                                      421974.065384
# 35                                      433489.361128
# 36                                      445153.639368
# 37                                      457163.750186
# 38                                      469465.814899
# 39                                      481816.497611
# 40                                      493964.565222
# 41                                      505819.396579
# 42                                      517495.267620
# 43                                      529214.386892
# 44                                      541147.666390
# 45                                      553305.805493
# 46                                      565548.317672
# 47                                      577692.571123
# 48                                      589639.958909
# 49                                      601433.244406
#
#     Base Case of Total Vaccinated rate from begining to the next 50 days
# 0                                        3.016411e+07
# 1                                        3.017773e+07
# 2                                        3.019192e+07
# 3                                        3.020610e+07
# 4                                        3.021865e+07
# 5                                        3.022906e+07
# 6                                        3.023885e+07
# 7                                        3.024950e+07
# 8                                        3.026174e+07
# 9                                        3.027530e+07
# 10                                       3.028899e+07
# 11                                       3.030162e+07
# 12                                       3.031290e+07
# 13                                       3.032342e+07
# 14                                       3.033423e+07
# 15                                       3.034609e+07
# 16                                       3.035897e+07
# 17                                       3.037217e+07
# 18                                       3.038484e+07
# 19                                       3.039658e+07
# 20                                       3.040764e+07
# 21                                       3.041871e+07
# 22                                       3.043039e+07
# 23                                       3.044283e+07
# 24                                       3.045564e+07
# 25                                       3.046823e+07
# 26                                       3.048022e+07
# 27                                       3.049166e+07
# 28                                       3.050297e+07
# 29                                       3.051461e+07
# 30                                       3.052677e+07
# 31                                       3.053929e+07
# 32                                       3.055176e+07
# 33                                       3.056387e+07
# 34                                       3.057557e+07
# 35                                       3.058708e+07
# 36                                       3.059875e+07
# 37                                       3.061076e+07
# 38                                       3.062306e+07
# 39                                       3.063541e+07
# 40                                       3.064756e+07
# 41                                       3.065941e+07
# 42                                       3.067109e+07
# 43                                       3.068281e+07
# 44                                       3.069474e+07
# 45                                       3.070690e+07
# 46                                       3.071914e+07
# 47                                       3.073129e+07
# 48                                       3.074323e+07
# 49                                       3.075503e+07

# %%
#lower_series --- worst case

worst_case = lower_series/100 - final_day_vacc_rate
worst_case_total = lower_series/100
worst_case_increase_num = worst_case*canada_population
worst_case_num_total = worst_case_total*canada_population
worst_case_summary_df = pd.concat([worst_case_increase_num, worst_case_num_total],axis=1)
worst_case_summary_df.columns = ['Worst Case of Number of vaccinated rate in 50 days (only in these 50 days)','Worst Case of Total Vaccinated rate from begining to the next 50 days']
worst_case_summary_df = worst_case_summary_df.reset_index().iloc[:,1:]
worst_case_summary_df
# Out:
#     Worst Case of Number of vaccinated rate in 50 days (only in these 50 days)  \
# 0                                        -6152.270318
# 1                                        -4386.202495
# 2                                        -1420.714831
# 3                                         -496.426102
# 4                                         -998.525478
# 5                                        -4274.221074
# 6                                       -10190.123649
# 7                                       -17040.270455
# 8                                       -23806.271860
# 9                                       -30252.787395
# 10                                      -36910.319140
# 11                                      -44818.576307
# 12                                      -54582.465611
# 13                                      -65976.058871
# 14                                      -78224.829235
# 15                                      -90545.346732
# 16                                     -102664.775010
# 17                                     -114955.823505
# 18                                     -128098.151960
# 19                                     -142569.797528
# 20                                     -158330.614138
# 21                                     -174889.899332
# 22                                     -191676.425976
# 23                                     -208425.099771
# 24                                     -225317.811698
# 25                                     -242809.566566
# 26                                     -261285.906283
# 27                                     -280800.566222
# 28                                     -301065.187133
# 29                                     -321672.090252
# 30                                     -342375.260935
# 31                                     -363234.812304
# 32                                     -384541.349891
# 33                                     -406592.274472
# 34                                     -429485.346049
# 35                                     -453067.586041
# 36                                     -477058.640829
# 37                                     -501247.802707
# 38                                     -525624.781356
# 39                                     -550363.013616
# 40                                     -575681.150868
# 41                                     -601687.756486
# 42                                     -628315.499801
# 43                                     -655380.357347
# 44                                     -682713.505694
# 45                                     -710270.017293
# 46                                     -738143.724841
# 47                                     -766487.541137
# 48                                     -795402.014880
# 49                                     -824870.132840
#
#     Worst Case of Total Vaccinated rate from begining to the next 50 days
# 0                                        3.014744e+07
# 1                                        3.014921e+07
# 2                                        3.015217e+07
# 3                                        3.015310e+07
# 4                                        3.015260e+07
# 5                                        3.014932e+07
# 6                                        3.014340e+07
# 7                                        3.013655e+07
# 8                                        3.012979e+07
# 9                                        3.012334e+07
# 10                                       3.011668e+07
# 11                                       3.010878e+07
# 12                                       3.009901e+07
# 13                                       3.008762e+07
# 14                                       3.007537e+07
# 15                                       3.006305e+07
# 16                                       3.005093e+07
# 17                                       3.003864e+07
# 18                                       3.002550e+07
# 19                                       3.001102e+07
# 20                                       2.999526e+07
# 21                                       2.997870e+07
# 22                                       2.996192e+07
# 23                                       2.994517e+07
# 24                                       2.992828e+07
# 25                                       2.991078e+07
# 26                                       2.989231e+07
# 27                                       2.987279e+07
# 28                                       2.985253e+07
# 29                                       2.983192e+07
# 30                                       2.981122e+07
# 31                                       2.979036e+07
# 32                                       2.976905e+07
# 33                                       2.974700e+07
# 34                                       2.972411e+07
# 35                                       2.970053e+07
# 36                                       2.967654e+07
# 37                                       2.965235e+07
# 38                                       2.962797e+07
# 39                                       2.960323e+07
# 40                                       2.957791e+07
# 41                                       2.955191e+07
# 42                                       2.952528e+07
# 43                                       2.949821e+07
# 44                                       2.947088e+07
# 45                                       2.944332e+07
# 46                                       2.941545e+07
# 47                                       2.938711e+07
# 48                                       2.935819e+07
# 49                                       2.932872e+07

# %% [markdown]
# Worst-Case Scenario: which shows that we forecast that the number of people vaccinate (left-side column)in next 50 days is decrease from the first day (6152 people get vaccinated) to the final day (824870 people get vaccinated in these 50 days. ), in other words, the from now on to the next 50 days, there will 2318170 people get vaccinated.
#
#  This worst-case scenario dataframe (right-side column) shows that the predict total number of people get vaccinated from the very begining which is 30147440 unitil the next 50 days is 29328720 for the whole time period from very beginning to the next 50 days.

# %%
##upper_series

best_case=upper_series/100-final_day_vacc_rate
best_case_total=upper_series/100
best_case_increase_num=best_case*canada_population
best_case_num_total=best_case_total* canada_population
best_case_summary_df = pd.concat([best_case_increase_num,best_case_num_total],axis=1)
best_case_summary_df.columns=['Best Case of Number of vaccinated rate in 50 days (only in these 50 days)','Best Case of Total Vaccinated rate from begining to the next 50 days']
best_case_summary_df=best_case_summary_df.reset_index().iloc[:,1:]
best_case_summary_df
# Out:
#     Best Case of Number of vaccinated rate in 50 days (only in these 50 days)  \
# 0                                        2.718609e+04
# 1                                        5.266086e+04
# 2                                        7.807215e+04
# 3                                        1.055093e+05
# 4                                        1.311156e+05
# 5                                        1.551976e+05
# 6                                        1.806971e+05
# 7                                        2.088596e+05
# 8                                        2.400983e+05
# 9                                        2.736682e+05
# 10                                       3.076933e+05
# 11                                       3.408723e+05
# 12                                       3.731906e+05
# 13                                       4.056280e+05
# 14                                       4.394997e+05
# 15                                       4.755377e+05
# 16                                       5.134193e+05
# 17                                       5.521069e+05
# 18                                       5.905950e+05
# 19                                       6.285442e+05
# 20                                       6.664262e+05
# 21                                       7.051180e+05
# 22                                       7.452691e+05
# 23                                       7.868896e+05
# 24                                       8.294030e+05
# 25                                       8.720825e+05
# 26                                       9.145397e+05
# 27                                       9.569387e+05
# 28                                       9.998220e+05
# 29                                       1.043706e+06
# 30                                       1.088737e+06
# 31                                       1.134626e+06
# 32                                       1.180880e+06
# 33                                       1.227149e+06
# 34                                       1.273433e+06
# 35                                       1.320046e+06
# 36                                       1.367366e+06
# 37                                       1.415575e+06
# 38                                       1.464556e+06
# 39                                       1.513996e+06
# 40                                       1.563610e+06
# 41                                       1.613327e+06
# 42                                       1.663306e+06
# 43                                       1.713809e+06
# 44                                       1.765009e+06
# 45                                       1.816882e+06
# 46                                       1.869240e+06
# 47                                       1.921873e+06
# 48                                       1.974682e+06
# 49                                       2.027737e+06
#
#     Best Case of Total Vaccinated rate from begining to the next 50 days
# 0                                        3.018078e+07
# 1                                        3.020625e+07
# 2                                        3.023167e+07
# 3                                        3.025910e+07
# 4                                        3.028471e+07
# 5                                        3.030879e+07
# 6                                        3.033429e+07
# 7                                        3.036245e+07
# 8                                        3.039369e+07
# 9                                        3.042726e+07
# 10                                       3.046129e+07
# 11                                       3.049447e+07
# 12                                       3.052678e+07
# 13                                       3.055922e+07
# 14                                       3.059309e+07
# 15                                       3.062913e+07
# 16                                       3.066701e+07
# 17                                       3.070570e+07
# 18                                       3.074419e+07
# 19                                       3.078214e+07
# 20                                       3.082002e+07
# 21                                       3.085871e+07
# 22                                       3.089886e+07
# 23                                       3.094048e+07
# 24                                       3.098300e+07
# 25                                       3.102568e+07
# 26                                       3.106813e+07
# 27                                       3.111053e+07
# 28                                       3.115342e+07
# 29                                       3.119730e+07
# 30                                       3.124233e+07
# 31                                       3.128822e+07
# 32                                       3.133447e+07
# 33                                       3.138074e+07
# 34                                       3.142703e+07
# 35                                       3.147364e+07
# 36                                       3.152096e+07
# 37                                       3.156917e+07
# 38                                       3.161815e+07
# 39                                       3.166759e+07
# 40                                       3.171720e+07
# 41                                       3.176692e+07
# 42                                       3.181690e+07
# 43                                       3.186740e+07
# 44                                       3.191860e+07
# 45                                       3.197048e+07
# 46                                       3.202283e+07
# 47                                       3.207547e+07
# 48                                       3.212828e+07
# 49                                       3.218133e+07

# %% [markdown]
# Best-Case Scenario: which shows that we forecast that the number of people vaccinate (left-side column)in next 50 days is increase from the first day (27186 people get vaccinated) to the final day (2027737 people get vaccinated in these 50 days. ), in other words, the from now on to the next 50 days, there will 2318170 people get vaccinated.
#
#  This best-case scenario dataframe (right-side column) shows that the predict total number of people get vaccinated from the very begining unitil the next 50 days is 32181330 for the whole time period from very beginning to the next 50 days.
